# %%
api_key = ""

# %%
import requests
import json
import time

# Define the API endpoint and your API key
base_url = "https://api.eia.gov/v2/electricity/rto/fuel-type-data/data/"

# Pagination settings
page_size = 5000
offset = 0

# This list will store all of the retrieved data
all_data = []

while True:
    # Construct the query parameters for the URL, including the API key
    params = {
        "api_key": api_key,  # Include the API key here
        "frequency": "hourly",
        "data[0]": "value",
        "start": "2024-01-01T00",
        "end": "2024-12-31T00",
        "sort[0][column]": "period",
        "sort[0][direction]": "desc",
        "offset": offset,
        "length": page_size
    }

    # Construct the header parameters (as a JSON string for X-Params)
    header_params = {
        "frequency": "hourly",
        "data": ["value"],
        "facets": {},
        "start": "2024-01-01T00",
        "end": "2024-12-31T00",
        "sort": [{"column": "period", "direction": "desc"}],
        "offset": offset,
        "length": page_size
    }

    headers = {
        "X-Params": json.dumps(header_params)
    }

    print(f"Requesting rows with offset {offset}...")

    # Make the GET request
    response = requests.get(base_url, params=params, headers=headers)

    # Check for a successful response
    if response.status_code != 200:
        print(f"Error: Received status code {response.status_code}")
        print("Response:", response.text)
        break

    # Parse the JSON response
    json_response = response.json()
   #Convert JSON responses returned by API into dictionaries
    # Assuming the API returns the data rows under the "data" key.
    page_data = json_response["response"].get("data", [])

    # If no data is returned, we've reached the end
    if not page_data:
        print("No more data returned; exiting pagination loop.")
        break

    # Add the page of data to our main list
    all_data.extend(page_data)
    print(f"Retrieved {len(page_data)} rows (total so far: {len(all_data)})")

    # If fewer rows than the page size were returned, this was the last page.
    if len(page_data) < page_size:
        print("Last page reached.")
        break

    # Increase the offset by the page size for the next iteration
    offset += page_size

    # Optional: pause between requests to avoid overwhelming the API
    time.sleep(3)

print("Finished retrieving data.")
print("Total rows fetched:", len(all_data))
# Out:
# Requesting rows with offset 0...
# Retrieved 5000 rows (total so far: 5000)
# Requesting rows with offset 5000...
# Retrieved 5000 rows (total so far: 10000)
# Requesting rows with offset 10000...
# Retrieved 5000 rows (total so far: 15000)
# Requesting rows with offset 15000...
# Retrieved 5000 rows (total so far: 20000)
# Requesting rows with offset 20000...
# Retrieved 5000 rows (total so far: 25000)
# Requesting rows with offset 25000...
# Retrieved 5000 rows (total so far: 30000)
# Requesting rows with offset 30000...
# Retrieved 5000 rows (total so far: 35000)
# Requesting rows with offset 35000...
# Retrieved 5000 rows (total so far: 40000)
# Requesting rows with offset 40000...
# Retrieved 5000 rows (total so far: 45000)
# Requesting rows with offset 45000...
# Retrieved 5000 rows (total so far: 50000)
# Requesting rows with offset 50000...
# Retrieved 5000 rows (total so far: 55000)
# Requesting rows with offset 55000...
# Retrieved 5000 rows (total so far: 60000)
# Requesting rows with offset 60000...
# Retrieved 5000 rows (total so far: 65000)
# Requesting rows with offset 65000...
# Retrieved 5000 rows (total so far: 70000)
# Requesting rows with offset 70000...
# Retrieved 5000 rows (total so far: 75000)
# Requesting rows with offset 75000...
# Retrieved 5000 rows (total so far: 80000)
# Requesting rows with offset 80000...
# Retrieved 5000 rows (total so far: 85000)
# Requesting rows with offset 85000...
# Retrieved 5000 rows (total so far: 90000)
# Requesting rows with offset 90000...
# Retrieved 5000 rows (total so far: 95000)
# Requesting rows with offset 95000...
# Retrieved 5000 rows (total so far: 100000)
# Requesting rows with offset 100000...
# Retrieved 5000 rows (total so far: 105000)
# Requesting rows with offset 105000...
# Retrieved 5000 rows (total so far: 110000)
# Requesting rows with offset 110000...
# Retrieved 5000 rows (total so far: 115000)
# Requesting rows with offset 115000...
# Retrieved 5000 rows (total so far: 120000)
# Requesting rows with offset 120000...
# Retrieved 5000 rows (total so far: 125000)
# Requesting rows with offset 125000...
# Retrieved 5000 rows (total so far: 130000)
# Requesting rows with offset 130000...
# Retrieved 5000 rows (total so far: 135000)
# Requesting rows with offset 135000...
# Retrieved 5000 rows (total so far: 140000)
# Requesting rows with offset 140000...
# Retrieved 5000 rows (total so far: 145000)
# Requesting rows with offset 145000...
# Retrieved 5000 rows (total so far: 150000)
# Requesting rows with offset 150000...
# Retrieved 5000 rows (total so far: 155000)
# Requesting rows with offset 155000...
# Retrieved 5000 rows (total so far: 160000)
# Requesting rows with offset 160000...
# Retrieved 5000 rows (total so far: 165000)
# Requesting rows with offset 165000...
# Retrieved 5000 rows (total so far: 170000)
# Requesting rows with offset 170000...
# Retrieved 5000 rows (total so far: 175000)
# Requesting rows with offset 175000...
# Retrieved 5000 rows (total so far: 180000)
# Requesting rows with offset 180000...
# Retrieved 5000 rows (total so far: 185000)
# Requesting rows with offset 185000...
# Retrieved 5000 rows (total so far: 190000)
# Requesting rows with offset 190000...
# Retrieved 5000 rows (total so far: 195000)
# Requesting rows with offset 195000...
# Retrieved 5000 rows (total so far: 200000)
# Requesting rows with offset 200000...
# Retrieved 5000 rows (total so far: 205000)
# Requesting rows with offset 205000...
# Retrieved 5000 rows (total so far: 210000)
# Requesting rows with offset 210000...
# Retrieved 5000 rows (total so far: 215000)
# Requesting rows with offset 215000...
# Retrieved 5000 rows (total so far: 220000)
# Requesting rows with offset 220000...
# Retrieved 5000 rows (total so far: 225000)
# Requesting rows with offset 225000...
# Retrieved 5000 rows (total so far: 230000)
# Requesting rows with offset 230000...
# Retrieved 5000 rows (total so far: 235000)
# Requesting rows with offset 235000...
# Retrieved 5000 rows (total so far: 240000)
# Requesting rows with offset 240000...
# Retrieved 5000 rows (total so far: 245000)
# Requesting rows with offset 245000...
# Retrieved 5000 rows (total so far: 250000)
# Requesting rows with offset 250000...
# Retrieved 5000 rows (total so far: 255000)
# Requesting rows with offset 255000...
# Retrieved 5000 rows (total so far: 260000)
# Requesting rows with offset 260000...
# Retrieved 5000 rows (total so far: 265000)
# Requesting rows with offset 265000...
# Retrieved 5000 rows (total so far: 270000)
# Requesting rows with offset 270000...
# Retrieved 5000 rows (total so far: 275000)
# Requesting rows with offset 275000...
# Retrieved 5000 rows (total so far: 280000)
# Requesting rows with offset 280000...
# Retrieved 5000 rows (total so far: 285000)
# Requesting rows with offset 285000...
# Retrieved 5000 rows (total so far: 290000)
# Requesting rows with offset 290000...
# Retrieved 5000 rows (total so far: 295000)
# Requesting rows with offset 295000...
# Retrieved 5000 rows (total so far: 300000)
# Requesting rows with offset 300000...
# Retrieved 5000 rows (total so far: 305000)
# Requesting rows with offset 305000...
# Retrieved 5000 rows (total so far: 310000)
# Requesting rows with offset 310000...
# Retrieved 5000 rows (total so far: 315000)
# Requesting rows with offset 315000...
# Retrieved 5000 rows (total so far: 320000)
# Requesting rows with offset 320000...
# Retrieved 5000 rows (total so far: 325000)
# Requesting rows with offset 325000...
# Retrieved 5000 rows (total so far: 330000)
# Requesting rows with offset 330000...
# Retrieved 5000 rows (total so far: 335000)
# Requesting rows with offset 335000...
# Retrieved 5000 rows (total so far: 340000)
# Requesting rows with offset 340000...
# Retrieved 5000 rows (total so far: 345000)
# Requesting rows with offset 345000...
# Retrieved 5000 rows (total so far: 350000)
# Requesting rows with offset 350000...
# Retrieved 5000 rows (total so far: 355000)
# Requesting rows with offset 355000...
# Retrieved 5000 rows (total so far: 360000)
# Requesting rows with offset 360000...
# Retrieved 5000 rows (total so far: 365000)
# Requesting rows with offset 365000...
# Retrieved 5000 rows (total so far: 370000)
# Requesting rows with offset 370000...
# Retrieved 5000 rows (total so far: 375000)
# Requesting rows with offset 375000...
# Retrieved 5000 rows (total so far: 380000)
# Requesting rows with offset 380000...
# Retrieved 5000 rows (total so far: 385000)
# Requesting rows with offset 385000...
# Retrieved 5000 rows (total so far: 390000)
# Requesting rows with offset 390000...
# Retrieved 5000 rows (total so far: 395000)
# Requesting rows with offset 395000...
# Retrieved 5000 rows (total so far: 400000)
# Requesting rows with offset 400000...
# Retrieved 5000 rows (total so far: 405000)
# Requesting rows with offset 405000...
# Retrieved 5000 rows (total so far: 410000)
# Requesting rows with offset 410000...
# Retrieved 5000 rows (total so far: 415000)
# Requesting rows with offset 415000...
# Retrieved 5000 rows (total so far: 420000)
# Requesting rows with offset 420000...
# Retrieved 5000 rows (total so far: 425000)
# Requesting rows with offset 425000...
# Retrieved 5000 rows (total so far: 430000)
# Requesting rows with offset 430000...
# Retrieved 5000 rows (total so far: 435000)
# Requesting rows with offset 435000...
# Retrieved 5000 rows (total so far: 440000)
# Requesting rows with offset 440000...
# Retrieved 5000 rows (total so far: 445000)
# Requesting rows with offset 445000...
# Retrieved 5000 rows (total so far: 450000)
# Requesting rows with offset 450000...
# Retrieved 5000 rows (total so far: 455000)
# Requesting rows with offset 455000...
# Retrieved 5000 rows (total so far: 460000)
# Requesting rows with offset 460000...
# Retrieved 5000 rows (total so far: 465000)
# Requesting rows with offset 465000...
# Retrieved 5000 rows (total so far: 470000)
# Requesting rows with offset 470000...
# Retrieved 5000 rows (total so far: 475000)
# Requesting rows with offset 475000...
# Retrieved 5000 rows (total so far: 480000)
# Requesting rows with offset 480000...
# Retrieved 5000 rows (total so far: 485000)
# Requesting rows with offset 485000...
# Retrieved 5000 rows (total so far: 490000)
# Requesting rows with offset 490000...
# Retrieved 5000 rows (total so far: 495000)
# Requesting rows with offset 495000...
# Retrieved 5000 rows (total so far: 500000)
# Requesting rows with offset 500000...
# Retrieved 5000 rows (total so far: 505000)
# Requesting rows with offset 505000...
# Retrieved 5000 rows (total so far: 510000)
# Requesting rows with offset 510000...
# Retrieved 5000 rows (total so far: 515000)
# Requesting rows with offset 515000...
# Retrieved 5000 rows (total so far: 520000)
# Requesting rows with offset 520000...
# Retrieved 5000 rows (total so far: 525000)
# Requesting rows with offset 525000...
# Retrieved 5000 rows (total so far: 530000)
# Requesting rows with offset 530000...
# Retrieved 5000 rows (total so far: 535000)
# Requesting rows with offset 535000...
# Retrieved 5000 rows (total so far: 540000)
# Requesting rows with offset 540000...
# Retrieved 5000 rows (total so far: 545000)
# Requesting rows with offset 545000...
# Retrieved 5000 rows (total so far: 550000)
# Requesting rows with offset 550000...
# Retrieved 5000 rows (total so far: 555000)
# Requesting rows with offset 555000...
# Retrieved 5000 rows (total so far: 560000)
# Requesting rows with offset 560000...
# Retrieved 5000 rows (total so far: 565000)
# Requesting rows with offset 565000...
# Retrieved 5000 rows (total so far: 570000)
# Requesting rows with offset 570000...
# Retrieved 5000 rows (total so far: 575000)
# Requesting rows with offset 575000...
# Retrieved 5000 rows (total so far: 580000)
# Requesting rows with offset 580000...
# Retrieved 5000 rows (total so far: 585000)
# Requesting rows with offset 585000...
# Retrieved 5000 rows (total so far: 590000)
# Requesting rows with offset 590000...
# Retrieved 5000 rows (total so far: 595000)
# Requesting rows with offset 595000...
# Retrieved 5000 rows (total so far: 600000)
# Requesting rows with offset 600000...
# Retrieved 5000 rows (total so far: 605000)
# Requesting rows with offset 605000...
# Retrieved 5000 rows (total so far: 610000)
# Requesting rows with offset 610000...
# Retrieved 5000 rows (total so far: 615000)
# Requesting rows with offset 615000...
# Retrieved 5000 rows (total so far: 620000)
# Requesting rows with offset 620000...
# Retrieved 5000 rows (total so far: 625000)
# Requesting rows with offset 625000...
# Retrieved 5000 rows (total so far: 630000)
# Requesting rows with offset 630000...
# Retrieved 5000 rows (total so far: 635000)
# Requesting rows with offset 635000...
# Retrieved 5000 rows (total so far: 640000)
# Requesting rows with offset 640000...
# Retrieved 5000 rows (total so far: 645000)
# Requesting rows with offset 645000...
# Retrieved 5000 rows (total so far: 650000)
# Requesting rows with offset 650000...
# Retrieved 5000 rows (total so far: 655000)
# Requesting rows with offset 655000...
# Retrieved 5000 rows (total so far: 660000)
# Requesting rows with offset 660000...
# Retrieved 5000 rows (total so far: 665000)
# Requesting rows with offset 665000...
# Retrieved 5000 rows (total so far: 670000)
# Requesting rows with offset 670000...
# Retrieved 5000 rows (total so far: 675000)
# Requesting rows with offset 675000...
# Retrieved 5000 rows (total so far: 680000)
# Requesting rows with offset 680000...
# Retrieved 5000 rows (total so far: 685000)
# Requesting rows with offset 685000...
# Retrieved 5000 rows (total so far: 690000)
# Requesting rows with offset 690000...
# Retrieved 5000 rows (total so far: 695000)
# Requesting rows with offset 695000...
# Retrieved 5000 rows (total so far: 700000)
# Requesting rows with offset 700000...
# Retrieved 5000 rows (total so far: 705000)
# Requesting rows with offset 705000...
# Retrieved 5000 rows (total so far: 710000)
# Requesting rows with offset 710000...
# Retrieved 5000 rows (total so far: 715000)
# Requesting rows with offset 715000...
# Retrieved 5000 rows (total so far: 720000)
# Requesting rows with offset 720000...
# Retrieved 5000 rows (total so far: 725000)
# Requesting rows with offset 725000...
# Retrieved 5000 rows (total so far: 730000)
# Requesting rows with offset 730000...
# Retrieved 5000 rows (total so far: 735000)
# Requesting rows with offset 735000...
# Retrieved 5000 rows (total so far: 740000)
# Requesting rows with offset 740000...
# Retrieved 5000 rows (total so far: 745000)
# Requesting rows with offset 745000...
# Retrieved 5000 rows (total so far: 750000)
# Requesting rows with offset 750000...
# Retrieved 5000 rows (total so far: 755000)
# Requesting rows with offset 755000...
# Retrieved 5000 rows (total so far: 760000)
# Requesting rows with offset 760000...
# Retrieved 5000 rows (total so far: 765000)
# Requesting rows with offset 765000...
# Retrieved 5000 rows (total so far: 770000)
# Requesting rows with offset 770000...
# Retrieved 5000 rows (total so far: 775000)
# Requesting rows with offset 775000...
# Retrieved 5000 rows (total so far: 780000)
# Requesting rows with offset 780000...
# Retrieved 5000 rows (total so far: 785000)
# Requesting rows with offset 785000...
# Retrieved 5000 rows (total so far: 790000)
# Requesting rows with offset 790000...
# Retrieved 5000 rows (total so far: 795000)
# Requesting rows with offset 795000...
# Retrieved 5000 rows (total so far: 800000)
# Requesting rows with offset 800000...
# Retrieved 5000 rows (total so far: 805000)
# Requesting rows with offset 805000...
# Retrieved 5000 rows (total so far: 810000)
# Requesting rows with offset 810000...
# Retrieved 5000 rows (total so far: 815000)
# Requesting rows with offset 815000...
# Retrieved 5000 rows (total so far: 820000)
# Requesting rows with offset 820000...
# Retrieved 5000 rows (total so far: 825000)
# Requesting rows with offset 825000...
# Retrieved 5000 rows (total so far: 830000)
# Requesting rows with offset 830000...
# Retrieved 5000 rows (total so far: 835000)
# Requesting rows with offset 835000...
# Retrieved 5000 rows (total so far: 840000)
# Requesting rows with offset 840000...
# Retrieved 5000 rows (total so far: 845000)
# Requesting rows with offset 845000...
# Retrieved 5000 rows (total so far: 850000)
# Requesting rows with offset 850000...
# Retrieved 5000 rows (total so far: 855000)
# Requesting rows with offset 855000...
# Retrieved 5000 rows (total so far: 860000)
# Requesting rows with offset 860000...
# Retrieved 5000 rows (total so far: 865000)
# Requesting rows with offset 865000...
# Retrieved 5000 rows (total so far: 870000)
# Requesting rows with offset 870000...
# Retrieved 5000 rows (total so far: 875000)
# Requesting rows with offset 875000...
# Retrieved 5000 rows (total so far: 880000)
# Requesting rows with offset 880000...
# Retrieved 5000 rows (total so far: 885000)
# Requesting rows with offset 885000...
# Retrieved 5000 rows (total so far: 890000)
# Requesting rows with offset 890000...
# Retrieved 5000 rows (total so far: 895000)
# Requesting rows with offset 895000...
# Retrieved 5000 rows (total so far: 900000)
# Requesting rows with offset 900000...
# Retrieved 5000 rows (total so far: 905000)
# Requesting rows with offset 905000...
# Retrieved 5000 rows (total so far: 910000)
# Requesting rows with offset 910000...
# Retrieved 5000 rows (total so far: 915000)
# Requesting rows with offset 915000...
# Retrieved 5000 rows (total so far: 920000)
# Requesting rows with offset 920000...
# Retrieved 5000 rows (total so far: 925000)
# Requesting rows with offset 925000...
# Retrieved 5000 rows (total so far: 930000)
# Requesting rows with offset 930000...
# Retrieved 5000 rows (total so far: 935000)
# Requesting rows with offset 935000...
# Retrieved 5000 rows (total so far: 940000)
# Requesting rows with offset 940000...
# Retrieved 5000 rows (total so far: 945000)
# Requesting rows with offset 945000...
# Retrieved 5000 rows (total so far: 950000)
# Requesting rows with offset 950000...
# Retrieved 5000 rows (total so far: 955000)
# Requesting rows with offset 955000...
# Retrieved 5000 rows (total so far: 960000)
# Requesting rows with offset 960000...
# Retrieved 5000 rows (total so far: 965000)
# Requesting rows with offset 965000...
# Retrieved 5000 rows (total so far: 970000)
# Requesting rows with offset 970000...
# Retrieved 5000 rows (total so far: 975000)
# Requesting rows with offset 975000...
# Retrieved 5000 rows (total so far: 980000)
# Requesting rows with offset 980000...
# Retrieved 5000 rows (total so far: 985000)
# Requesting rows with offset 985000...
# Retrieved 5000 rows (total so far: 990000)
# Requesting rows with offset 990000...
# Retrieved 5000 rows (total so far: 995000)
# Requesting rows with offset 995000...
# Retrieved 5000 rows (total so far: 1000000)
# Requesting rows with offset 1000000...
# Retrieved 5000 rows (total so far: 1005000)
# Requesting rows with offset 1005000...
# Retrieved 5000 rows (total so far: 1010000)
# Requesting rows with offset 1010000...
# Retrieved 5000 rows (total so far: 1015000)
# Requesting rows with offset 1015000...
# Retrieved 5000 rows (total so far: 1020000)
# Requesting rows with offset 1020000...
# Retrieved 5000 rows (total so far: 1025000)
# Requesting rows with offset 1025000...
# Retrieved 5000 rows (total so far: 1030000)
# Requesting rows with offset 1030000...
# Retrieved 5000 rows (total so far: 1035000)
# Requesting rows with offset 1035000...
# Retrieved 5000 rows (total so far: 1040000)
# Requesting rows with offset 1040000...
# Retrieved 5000 rows (total so far: 1045000)
# Requesting rows with offset 1045000...
# Retrieved 5000 rows (total so far: 1050000)
# Requesting rows with offset 1050000...
# Retrieved 5000 rows (total so far: 1055000)
# Requesting rows with offset 1055000...
# Retrieved 5000 rows (total so far: 1060000)
# Requesting rows with offset 1060000...
# Retrieved 5000 rows (total so far: 1065000)
# Requesting rows with offset 1065000...
# Retrieved 5000 rows (total so far: 1070000)
# Requesting rows with offset 1070000...
# Retrieved 5000 rows (total so far: 1075000)
# Requesting rows with offset 1075000...
# Retrieved 5000 rows (total so far: 1080000)
# Requesting rows with offset 1080000...
# Retrieved 5000 rows (total so far: 1085000)
# Requesting rows with offset 1085000...
# Retrieved 5000 rows (total so far: 1090000)
# Requesting rows with offset 1090000...
# Retrieved 5000 rows (total so far: 1095000)
# Requesting rows with offset 1095000...
# Retrieved 5000 rows (total so far: 1100000)
# Requesting rows with offset 1100000...
# Retrieved 5000 rows (total so far: 1105000)
# Requesting rows with offset 1105000...
# Retrieved 5000 rows (total so far: 1110000)
# Requesting rows with offset 1110000...
# Retrieved 5000 rows (total so far: 1115000)
# Requesting rows with offset 1115000...
# Retrieved 5000 rows (total so far: 1120000)
# Requesting rows with offset 1120000...
# Retrieved 5000 rows (total so far: 1125000)
# Requesting rows with offset 1125000...
# Retrieved 5000 rows (total so far: 1130000)
# Requesting rows with offset 1130000...
# Retrieved 5000 rows (total so far: 1135000)
# Requesting rows with offset 1135000...
# Retrieved 5000 rows (total so far: 1140000)
# Requesting rows with offset 1140000...
# Retrieved 5000 rows (total so far: 1145000)
# Requesting rows with offset 1145000...
# Retrieved 5000 rows (total so far: 1150000)
# Requesting rows with offset 1150000...
# Retrieved 5000 rows (total so far: 1155000)
# Requesting rows with offset 1155000...
# Retrieved 5000 rows (total so far: 1160000)
# Requesting rows with offset 1160000...
# Retrieved 5000 rows (total so far: 1165000)
# Requesting rows with offset 1165000...
# Retrieved 5000 rows (total so far: 1170000)
# Requesting rows with offset 1170000...
# Retrieved 5000 rows (total so far: 1175000)
# Requesting rows with offset 1175000...
# Retrieved 5000 rows (total so far: 1180000)
# Requesting rows with offset 1180000...
# Retrieved 5000 rows (total so far: 1185000)
# Requesting rows with offset 1185000...
# Retrieved 5000 rows (total so far: 1190000)
# Requesting rows with offset 1190000...
# Retrieved 5000 rows (total so far: 1195000)
# Requesting rows with offset 1195000...
# Retrieved 5000 rows (total so far: 1200000)
# Requesting rows with offset 1200000...
# Retrieved 5000 rows (total so far: 1205000)
# Requesting rows with offset 1205000...
# Retrieved 5000 rows (total so far: 1210000)
# Requesting rows with offset 1210000...
# Retrieved 5000 rows (total so far: 1215000)
# Requesting rows with offset 1215000...
# Retrieved 5000 rows (total so far: 1220000)
# Requesting rows with offset 1220000...
# Retrieved 5000 rows (total so far: 1225000)
# Requesting rows with offset 1225000...
# Retrieved 5000 rows (total so far: 1230000)
# Requesting rows with offset 1230000...
# Retrieved 5000 rows (total so far: 1235000)
# Requesting rows with offset 1235000...
# Retrieved 5000 rows (total so far: 1240000)
# Requesting rows with offset 1240000...
# Retrieved 5000 rows (total so far: 1245000)
# Requesting rows with offset 1245000...
# Retrieved 5000 rows (total so far: 1250000)
# Requesting rows with offset 1250000...
# Retrieved 5000 rows (total so far: 1255000)
# Requesting rows with offset 1255000...
# Retrieved 5000 rows (total so far: 1260000)
# Requesting rows with offset 1260000...
# Retrieved 5000 rows (total so far: 1265000)
# Requesting rows with offset 1265000...
# Retrieved 5000 rows (total so far: 1270000)
# Requesting rows with offset 1270000...
# Retrieved 5000 rows (total so far: 1275000)
# Requesting rows with offset 1275000...
# Retrieved 5000 rows (total so far: 1280000)
# Requesting rows with offset 1280000...
# Retrieved 5000 rows (total so far: 1285000)
# Requesting rows with offset 1285000...
# Retrieved 5000 rows (total so far: 1290000)
# Requesting rows with offset 1290000...
# Retrieved 5000 rows (total so far: 1295000)
# Requesting rows with offset 1295000...
# Retrieved 5000 rows (total so far: 1300000)
# Requesting rows with offset 1300000...
# Retrieved 5000 rows (total so far: 1305000)
# Requesting rows with offset 1305000...
# Retrieved 5000 rows (total so far: 1310000)
# Requesting rows with offset 1310000...
# Retrieved 5000 rows (total so far: 1315000)
# Requesting rows with offset 1315000...
# Retrieved 5000 rows (total so far: 1320000)
# Requesting rows with offset 1320000...
# Retrieved 5000 rows (total so far: 1325000)
# Requesting rows with offset 1325000...
# Retrieved 5000 rows (total so far: 1330000)
# Requesting rows with offset 1330000...
# Retrieved 5000 rows (total so far: 1335000)
# Requesting rows with offset 1335000...
# Retrieved 5000 rows (total so far: 1340000)
# Requesting rows with offset 1340000...
# Retrieved 5000 rows (total so far: 1345000)
# Requesting rows with offset 1345000...
# Retrieved 5000 rows (total so far: 1350000)
# Requesting rows with offset 1350000...
# Retrieved 5000 rows (total so far: 1355000)
# Requesting rows with offset 1355000...
# Retrieved 5000 rows (total so far: 1360000)
# Requesting rows with offset 1360000...
# Retrieved 5000 rows (total so far: 1365000)
# Requesting rows with offset 1365000...
# Retrieved 5000 rows (total so far: 1370000)
# Requesting rows with offset 1370000...
# Retrieved 5000 rows (total so far: 1375000)
# Requesting rows with offset 1375000...
# Retrieved 5000 rows (total so far: 1380000)
# Requesting rows with offset 1380000...
# Retrieved 5000 rows (total so far: 1385000)
# Requesting rows with offset 1385000...
# Retrieved 5000 rows (total so far: 1390000)
# Requesting rows with offset 1390000...
# Retrieved 5000 rows (total so far: 1395000)
# Requesting rows with offset 1395000...
# Retrieved 5000 rows (total so far: 1400000)
# Requesting rows with offset 1400000...
# Retrieved 5000 rows (total so far: 1405000)
# Requesting rows with offset 1405000...
# Retrieved 5000 rows (total so far: 1410000)
# Requesting rows with offset 1410000...
# Retrieved 5000 rows (total so far: 1415000)
# Requesting rows with offset 1415000...
# Retrieved 5000 rows (total so far: 1420000)
# Requesting rows with offset 1420000...
# Retrieved 5000 rows (total so far: 1425000)
# Requesting rows with offset 1425000...
# Retrieved 5000 rows (total so far: 1430000)
# Requesting rows with offset 1430000...
# Retrieved 5000 rows (total so far: 1435000)
# Requesting rows with offset 1435000...
# Retrieved 5000 rows (total so far: 1440000)
# Requesting rows with offset 1440000...
# Retrieved 5000 rows (total so far: 1445000)
# Requesting rows with offset 1445000...
# Retrieved 5000 rows (total so far: 1450000)
# Requesting rows with offset 1450000...
# Retrieved 5000 rows (total so far: 1455000)
# Requesting rows with offset 1455000...
# Retrieved 5000 rows (total so far: 1460000)
# Requesting rows with offset 1460000...
# Retrieved 5000 rows (total so far: 1465000)
# Requesting rows with offset 1465000...
# Retrieved 5000 rows (total so far: 1470000)
# Requesting rows with offset 1470000...
# Retrieved 5000 rows (total so far: 1475000)
# Requesting rows with offset 1475000...
# Retrieved 5000 rows (total so far: 1480000)
# Requesting rows with offset 1480000...
# Retrieved 5000 rows (total so far: 1485000)
# Requesting rows with offset 1485000...
# Retrieved 5000 rows (total so far: 1490000)
# Requesting rows with offset 1490000...
# Retrieved 5000 rows (total so far: 1495000)
# Requesting rows with offset 1495000...
# Retrieved 5000 rows (total so far: 1500000)
# Requesting rows with offset 1500000...
# Retrieved 5000 rows (total so far: 1505000)
# Requesting rows with offset 1505000...
# Retrieved 5000 rows (total so far: 1510000)
# Requesting rows with offset 1510000...
# Retrieved 5000 rows (total so far: 1515000)
# Requesting rows with offset 1515000...
# Retrieved 5000 rows (total so far: 1520000)
# Requesting rows with offset 1520000...
# Retrieved 5000 rows (total so far: 1525000)
# Requesting rows with offset 1525000...
# Retrieved 5000 rows (total so far: 1530000)
# Requesting rows with offset 1530000...
# Retrieved 5000 rows (total so far: 1535000)
# Requesting rows with offset 1535000...
# Retrieved 5000 rows (total so far: 1540000)
# Requesting rows with offset 1540000...
# Retrieved 5000 rows (total so far: 1545000)
# Requesting rows with offset 1545000...
# Retrieved 5000 rows (total so far: 1550000)
# Requesting rows with offset 1550000...
# Retrieved 5000 rows (total so far: 1555000)
# Requesting rows with offset 1555000...
# Retrieved 5000 rows (total so far: 1560000)
# Requesting rows with offset 1560000...
# Retrieved 5000 rows (total so far: 1565000)
# Requesting rows with offset 1565000...
# Retrieved 5000 rows (total so far: 1570000)
# Requesting rows with offset 1570000...
# Retrieved 5000 rows (total so far: 1575000)
# Requesting rows with offset 1575000...
# Retrieved 5000 rows (total so far: 1580000)
# Requesting rows with offset 1580000...
# Retrieved 5000 rows (total so far: 1585000)
# Requesting rows with offset 1585000...
# Retrieved 5000 rows (total so far: 1590000)
# Requesting rows with offset 1590000...
# Retrieved 5000 rows (total so far: 1595000)
# Requesting rows with offset 1595000...
# Retrieved 5000 rows (total so far: 1600000)
# Requesting rows with offset 1600000...
# Retrieved 5000 rows (total so far: 1605000)
# Requesting rows with offset 1605000...
# Retrieved 5000 rows (total so far: 1610000)
# Requesting rows with offset 1610000...
# Retrieved 5000 rows (total so far: 1615000)
# Requesting rows with offset 1615000...
# Retrieved 5000 rows (total so far: 1620000)
# Requesting rows with offset 1620000...
# Retrieved 5000 rows (total so far: 1625000)
# Requesting rows with offset 1625000...
# Retrieved 5000 rows (total so far: 1630000)
# Requesting rows with offset 1630000...
# Retrieved 5000 rows (total so far: 1635000)
# Requesting rows with offset 1635000...
# Retrieved 5000 rows (total so far: 1640000)
# Requesting rows with offset 1640000...
# Retrieved 5000 rows (total so far: 1645000)
# Requesting rows with offset 1645000...
# Retrieved 5000 rows (total so far: 1650000)
# Requesting rows with offset 1650000...
# Retrieved 5000 rows (total so far: 1655000)
# Requesting rows with offset 1655000...
# Retrieved 5000 rows (total so far: 1660000)
# Requesting rows with offset 1660000...
# Retrieved 5000 rows (total so far: 1665000)
# Requesting rows with offset 1665000...
# Retrieved 5000 rows (total so far: 1670000)
# Requesting rows with offset 1670000...
# Retrieved 5000 rows (total so far: 1675000)
# Requesting rows with offset 1675000...
# Retrieved 5000 rows (total so far: 1680000)
# Requesting rows with offset 1680000...
# Retrieved 5000 rows (total so far: 1685000)
# Requesting rows with offset 1685000...
# Retrieved 5000 rows (total so far: 1690000)
# Requesting rows with offset 1690000...
# Retrieved 5000 rows (total so far: 1695000)
# Requesting rows with offset 1695000...
# Retrieved 5000 rows (total so far: 1700000)
# Requesting rows with offset 1700000...
# Retrieved 5000 rows (total so far: 1705000)
# Requesting rows with offset 1705000...
# Retrieved 5000 rows (total so far: 1710000)
# Requesting rows with offset 1710000...
# Retrieved 5000 rows (total so far: 1715000)
# Requesting rows with offset 1715000...
# Retrieved 5000 rows (total so far: 1720000)
# Requesting rows with offset 1720000...
# Retrieved 5000 rows (total so far: 1725000)
# Requesting rows with offset 1725000...
# Retrieved 5000 rows (total so far: 1730000)
# Requesting rows with offset 1730000...
# Retrieved 5000 rows (total so far: 1735000)
# Requesting rows with offset 1735000...
# Retrieved 5000 rows (total so far: 1740000)
# Requesting rows with offset 1740000...
# Retrieved 5000 rows (total so far: 1745000)
# Requesting rows with offset 1745000...
# Retrieved 5000 rows (total so far: 1750000)
# Requesting rows with offset 1750000...
# Retrieved 5000 rows (total so far: 1755000)
# Requesting rows with offset 1755000...
# Retrieved 5000 rows (total so far: 1760000)
# Requesting rows with offset 1760000...
# Retrieved 5000 rows (total so far: 1765000)
# Requesting rows with offset 1765000...
# Retrieved 5000 rows (total so far: 1770000)
# Requesting rows with offset 1770000...
# Retrieved 5000 rows (total so far: 1775000)
# Requesting rows with offset 1775000...
# Retrieved 5000 rows (total so far: 1780000)
# Requesting rows with offset 1780000...
# Retrieved 5000 rows (total so far: 1785000)
# Requesting rows with offset 1785000...
# Retrieved 5000 rows (total so far: 1790000)
# Requesting rows with offset 1790000...
# Retrieved 5000 rows (total so far: 1795000)
# Requesting rows with offset 1795000...
# Retrieved 5000 rows (total so far: 1800000)
# Requesting rows with offset 1800000...
# Retrieved 5000 rows (total so far: 1805000)
# Requesting rows with offset 1805000...
# Retrieved 5000 rows (total so far: 1810000)
# Requesting rows with offset 1810000...
# Retrieved 5000 rows (total so far: 1815000)
# Requesting rows with offset 1815000...
# Retrieved 5000 rows (total so far: 1820000)
# Requesting rows with offset 1820000...
# Retrieved 5000 rows (total so far: 1825000)
# Requesting rows with offset 1825000...
# Retrieved 5000 rows (total so far: 1830000)
# Requesting rows with offset 1830000...
# Retrieved 5000 rows (total so far: 1835000)
# Requesting rows with offset 1835000...
# Retrieved 5000 rows (total so far: 1840000)
# Requesting rows with offset 1840000...
# Retrieved 5000 rows (total so far: 1845000)
# Requesting rows with offset 1845000...
# Retrieved 5000 rows (total so far: 1850000)
# Requesting rows with offset 1850000...
# Retrieved 5000 rows (total so far: 1855000)
# Requesting rows with offset 1855000...
# Retrieved 5000 rows (total so far: 1860000)
# Requesting rows with offset 1860000...
# Retrieved 5000 rows (total so far: 1865000)
# Requesting rows with offset 1865000...
# Retrieved 5000 rows (total so far: 1870000)
# Requesting rows with offset 1870000...
# Retrieved 5000 rows (total so far: 1875000)
# Requesting rows with offset 1875000...
# Retrieved 5000 rows (total so far: 1880000)
# Requesting rows with offset 1880000...
# Retrieved 5000 rows (total so far: 1885000)
# Requesting rows with offset 1885000...
# Retrieved 5000 rows (total so far: 1890000)
# Requesting rows with offset 1890000...
# Retrieved 5000 rows (total so far: 1895000)
# Requesting rows with offset 1895000...
# Retrieved 5000 rows (total so far: 1900000)
# Requesting rows with offset 1900000...
# Retrieved 5000 rows (total so far: 1905000)
# Requesting rows with offset 1905000...
# Retrieved 5000 rows (total so far: 1910000)
# Requesting rows with offset 1910000...
# Retrieved 5000 rows (total so far: 1915000)
# Requesting rows with offset 1915000...
# Retrieved 5000 rows (total so far: 1920000)
# Requesting rows with offset 1920000...
# Retrieved 5000 rows (total so far: 1925000)
# Requesting rows with offset 1925000...
# Retrieved 5000 rows (total so far: 1930000)
# Requesting rows with offset 1930000...
# Retrieved 5000 rows (total so far: 1935000)
# Requesting rows with offset 1935000...
# Retrieved 5000 rows (total so far: 1940000)
# Requesting rows with offset 1940000...
# Retrieved 5000 rows (total so far: 1945000)
# Requesting rows with offset 1945000...
# Retrieved 5000 rows (total so far: 1950000)
# Requesting rows with offset 1950000...
# Retrieved 5000 rows (total so far: 1955000)
# Requesting rows with offset 1955000...
# Retrieved 5000 rows (total so far: 1960000)
# Requesting rows with offset 1960000...
# Retrieved 5000 rows (total so far: 1965000)
# Requesting rows with offset 1965000...
# Retrieved 5000 rows (total so far: 1970000)
# Requesting rows with offset 1970000...
# Retrieved 5000 rows (total so far: 1975000)
# Requesting rows with offset 1975000...
# Retrieved 5000 rows (total so far: 1980000)
# Requesting rows with offset 1980000...
# Retrieved 5000 rows (total so far: 1985000)
# Requesting rows with offset 1985000...
# Retrieved 5000 rows (total so far: 1990000)
# Requesting rows with offset 1990000...
# Retrieved 5000 rows (total so far: 1995000)
# Requesting rows with offset 1995000...
# Retrieved 5000 rows (total so far: 2000000)
# Requesting rows with offset 2000000...
# Retrieved 5000 rows (total so far: 2005000)
# Requesting rows with offset 2005000...
# Retrieved 5000 rows (total so far: 2010000)
# Requesting rows with offset 2010000...
# Retrieved 5000 rows (total so far: 2015000)
# Requesting rows with offset 2015000...
# Retrieved 5000 rows (total so far: 2020000)
# Requesting rows with offset 2020000...
# Retrieved 5000 rows (total so far: 2025000)
# Requesting rows with offset 2025000...
# Retrieved 5000 rows (total so far: 2030000)
# Requesting rows with offset 2030000...
# Retrieved 5000 rows (total so far: 2035000)
# Requesting rows with offset 2035000...
# Retrieved 5000 rows (total so far: 2040000)
# Requesting rows with offset 2040000...
# Retrieved 5000 rows (total so far: 2045000)
# Requesting rows with offset 2045000...
# Retrieved 5000 rows (total so far: 2050000)
# Requesting rows with offset 2050000...
# Retrieved 5000 rows (total so far: 2055000)
# Requesting rows with offset 2055000...
# Retrieved 5000 rows (total so far: 2060000)
# Requesting rows with offset 2060000...
# Retrieved 5000 rows (total so far: 2065000)
# Requesting rows with offset 2065000...
# Retrieved 5000 rows (total so far: 2070000)
# Requesting rows with offset 2070000...
# Retrieved 5000 rows (total so far: 2075000)
# Requesting rows with offset 2075000...
# Retrieved 5000 rows (total so far: 2080000)
# Requesting rows with offset 2080000...
# Retrieved 5000 rows (total so far: 2085000)
# Requesting rows with offset 2085000...
# Retrieved 5000 rows (total so far: 2090000)
# Requesting rows with offset 2090000...
# Retrieved 5000 rows (total so far: 2095000)
# Requesting rows with offset 2095000...
# Retrieved 5000 rows (total so far: 2100000)
# Requesting rows with offset 2100000...
# Retrieved 5000 rows (total so far: 2105000)
# Requesting rows with offset 2105000...
# Retrieved 5000 rows (total so far: 2110000)
# Requesting rows with offset 2110000...
# Retrieved 5000 rows (total so far: 2115000)
# Requesting rows with offset 2115000...
# Retrieved 5000 rows (total so far: 2120000)
# Requesting rows with offset 2120000...
# Retrieved 5000 rows (total so far: 2125000)
# Requesting rows with offset 2125000...
# Retrieved 5000 rows (total so far: 2130000)
# Requesting rows with offset 2130000...
# Retrieved 5000 rows (total so far: 2135000)
# Requesting rows with offset 2135000...
# Retrieved 5000 rows (total so far: 2140000)
# Requesting rows with offset 2140000...
# Retrieved 5000 rows (total so far: 2145000)
# Requesting rows with offset 2145000...
# Retrieved 5000 rows (total so far: 2150000)
# Requesting rows with offset 2150000...
# Retrieved 5000 rows (total so far: 2155000)
# Requesting rows with offset 2155000...
# Retrieved 5000 rows (total so far: 2160000)
# Requesting rows with offset 2160000...
# Retrieved 5000 rows (total so far: 2165000)
# Requesting rows with offset 2165000...
# Retrieved 5000 rows (total so far: 2170000)
# Requesting rows with offset 2170000...
# Retrieved 5000 rows (total so far: 2175000)
# Requesting rows with offset 2175000...
# Retrieved 5000 rows (total so far: 2180000)
# Requesting rows with offset 2180000...
# Retrieved 5000 rows (total so far: 2185000)
# Requesting rows with offset 2185000...
# Retrieved 5000 rows (total so far: 2190000)
# Requesting rows with offset 2190000...
# Retrieved 5000 rows (total so far: 2195000)
# Requesting rows with offset 2195000...
# Retrieved 5000 rows (total so far: 2200000)
# Requesting rows with offset 2200000...
# Retrieved 5000 rows (total so far: 2205000)
# Requesting rows with offset 2205000...
# Retrieved 5000 rows (total so far: 2210000)
# Requesting rows with offset 2210000...
# Retrieved 5000 rows (total so far: 2215000)
# Requesting rows with offset 2215000...
# Retrieved 5000 rows (total so far: 2220000)
# Requesting rows with offset 2220000...
# Retrieved 5000 rows (total so far: 2225000)
# Requesting rows with offset 2225000...
# Retrieved 5000 rows (total so far: 2230000)
# Requesting rows with offset 2230000...
# Retrieved 5000 rows (total so far: 2235000)
# Requesting rows with offset 2235000...
# Retrieved 5000 rows (total so far: 2240000)
# Requesting rows with offset 2240000...
# Retrieved 5000 rows (total so far: 2245000)
# Requesting rows with offset 2245000...
# Retrieved 5000 rows (total so far: 2250000)
# Requesting rows with offset 2250000...
# Retrieved 5000 rows (total so far: 2255000)
# Requesting rows with offset 2255000...
# Retrieved 5000 rows (total so far: 2260000)
# Requesting rows with offset 2260000...
# Retrieved 5000 rows (total so far: 2265000)
# Requesting rows with offset 2265000...
# Retrieved 5000 rows (total so far: 2270000)
# Requesting rows with offset 2270000...
# Retrieved 5000 rows (total so far: 2275000)
# Requesting rows with offset 2275000...
# Retrieved 5000 rows (total so far: 2280000)
# Requesting rows with offset 2280000...
# Retrieved 5000 rows (total so far: 2285000)
# Requesting rows with offset 2285000...
# Retrieved 5000 rows (total so far: 2290000)
# Requesting rows with offset 2290000...
# Retrieved 5000 rows (total so far: 2295000)
# Requesting rows with offset 2295000...
# Retrieved 5000 rows (total so far: 2300000)
# Requesting rows with offset 2300000...
# Retrieved 5000 rows (total so far: 2305000)
# Requesting rows with offset 2305000...
# Retrieved 5000 rows (total so far: 2310000)
# Requesting rows with offset 2310000...
# Retrieved 5000 rows (total so far: 2315000)
# Requesting rows with offset 2315000...
# Retrieved 5000 rows (total so far: 2320000)
# Requesting rows with offset 2320000...
# Retrieved 5000 rows (total so far: 2325000)
# Requesting rows with offset 2325000...
# Retrieved 5000 rows (total so far: 2330000)
# Requesting rows with offset 2330000...
# Retrieved 5000 rows (total so far: 2335000)
# Requesting rows with offset 2335000...
# Retrieved 5000 rows (total so far: 2340000)
# Requesting rows with offset 2340000...
# Retrieved 5000 rows (total so far: 2345000)
# Requesting rows with offset 2345000...
# Retrieved 5000 rows (total so far: 2350000)
# Requesting rows with offset 2350000...
# Retrieved 5000 rows (total so far: 2355000)
# Requesting rows with offset 2355000...
# Retrieved 5000 rows (total so far: 2360000)
# Requesting rows with offset 2360000...
# Retrieved 5000 rows (total so far: 2365000)
# Requesting rows with offset 2365000...
# Retrieved 5000 rows (total so far: 2370000)
# Requesting rows with offset 2370000...
# Retrieved 5000 rows (total so far: 2375000)
# Requesting rows with offset 2375000...
# Retrieved 5000 rows (total so far: 2380000)
# Requesting rows with offset 2380000...
# Retrieved 5000 rows (total so far: 2385000)
# Requesting rows with offset 2385000...
# Retrieved 5000 rows (total so far: 2390000)
# Requesting rows with offset 2390000...
# Retrieved 5000 rows (total so far: 2395000)
# Requesting rows with offset 2395000...
# Retrieved 5000 rows (total so far: 2400000)
# Requesting rows with offset 2400000...
# Retrieved 5000 rows (total so far: 2405000)
# Requesting rows with offset 2405000...
# Retrieved 5000 rows (total so far: 2410000)
# Requesting rows with offset 2410000...
# Retrieved 5000 rows (total so far: 2415000)
# Requesting rows with offset 2415000...
# Retrieved 5000 rows (total so far: 2420000)
# Requesting rows with offset 2420000...
# Retrieved 5000 rows (total so far: 2425000)
# Requesting rows with offset 2425000...
# Retrieved 5000 rows (total so far: 2430000)
# Requesting rows with offset 2430000...
# Retrieved 5000 rows (total so far: 2435000)
# Requesting rows with offset 2435000...
# Retrieved 5000 rows (total so far: 2440000)
# Requesting rows with offset 2440000...
# Retrieved 5000 rows (total so far: 2445000)
# Requesting rows with offset 2445000...
# Retrieved 5000 rows (total so far: 2450000)
# Requesting rows with offset 2450000...
# Retrieved 5000 rows (total so far: 2455000)
# Requesting rows with offset 2455000...
# Retrieved 5000 rows (total so far: 2460000)
# Requesting rows with offset 2460000...
# Retrieved 5000 rows (total so far: 2465000)
# Requesting rows with offset 2465000...
# Retrieved 5000 rows (total so far: 2470000)
# Requesting rows with offset 2470000...
# Retrieved 5000 rows (total so far: 2475000)
# Requesting rows with offset 2475000...
# Retrieved 5000 rows (total so far: 2480000)
# Requesting rows with offset 2480000...
# Retrieved 5000 rows (total so far: 2485000)
# Requesting rows with offset 2485000...
# Retrieved 5000 rows (total so far: 2490000)
# Requesting rows with offset 2490000...
# Retrieved 5000 rows (total so far: 2495000)
# Requesting rows with offset 2495000...
# Retrieved 5000 rows (total so far: 2500000)
# Requesting rows with offset 2500000...
# Retrieved 5000 rows (total so far: 2505000)
# Requesting rows with offset 2505000...
# Retrieved 5000 rows (total so far: 2510000)
# Requesting rows with offset 2510000...
# Retrieved 5000 rows (total so far: 2515000)
# Requesting rows with offset 2515000...
# Retrieved 5000 rows (total so far: 2520000)
# Requesting rows with offset 2520000...
# Retrieved 5000 rows (total so far: 2525000)
# Requesting rows with offset 2525000...
# Retrieved 5000 rows (total so far: 2530000)
# Requesting rows with offset 2530000...
# Retrieved 5000 rows (total so far: 2535000)
# Requesting rows with offset 2535000...
# Retrieved 5000 rows (total so far: 2540000)
# Requesting rows with offset 2540000...
# Retrieved 5000 rows (total so far: 2545000)
# Requesting rows with offset 2545000...
# Retrieved 5000 rows (total so far: 2550000)
# Requesting rows with offset 2550000...
# Retrieved 5000 rows (total so far: 2555000)
# Requesting rows with offset 2555000...
# Retrieved 5000 rows (total so far: 2560000)
# Requesting rows with offset 2560000...
# Retrieved 5000 rows (total so far: 2565000)
# Requesting rows with offset 2565000...
# Retrieved 5000 rows (total so far: 2570000)
# Requesting rows with offset 2570000...
# Retrieved 5000 rows (total so far: 2575000)
# Requesting rows with offset 2575000...
# Retrieved 5000 rows (total so far: 2580000)
# Requesting rows with offset 2580000...
# Retrieved 5000 rows (total so far: 2585000)
# Requesting rows with offset 2585000...
# Retrieved 5000 rows (total so far: 2590000)
# Requesting rows with offset 2590000...
# Retrieved 5000 rows (total so far: 2595000)
# Requesting rows with offset 2595000...
# Retrieved 5000 rows (total so far: 2600000)
# Requesting rows with offset 2600000...
# Retrieved 5000 rows (total so far: 2605000)
# Requesting rows with offset 2605000...
# Retrieved 5000 rows (total so far: 2610000)
# Requesting rows with offset 2610000...
# Retrieved 5000 rows (total so far: 2615000)
# Requesting rows with offset 2615000...
# Retrieved 5000 rows (total so far: 2620000)
# Requesting rows with offset 2620000...
# Retrieved 5000 rows (total so far: 2625000)
# Requesting rows with offset 2625000...
# Retrieved 5000 rows (total so far: 2630000)
# Requesting rows with offset 2630000...
# Retrieved 5000 rows (total so far: 2635000)
# Requesting rows with offset 2635000...
# Retrieved 5000 rows (total so far: 2640000)
# Requesting rows with offset 2640000...
# Retrieved 5000 rows (total so far: 2645000)
# Requesting rows with offset 2645000...
# Retrieved 5000 rows (total so far: 2650000)
# Requesting rows with offset 2650000...
# Retrieved 5000 rows (total so far: 2655000)
# Requesting rows with offset 2655000...
# Retrieved 5000 rows (total so far: 2660000)
# Requesting rows with offset 2660000...
# Retrieved 5000 rows (total so far: 2665000)
# Requesting rows with offset 2665000...
# Retrieved 5000 rows (total so far: 2670000)
# Requesting rows with offset 2670000...
# Retrieved 5000 rows (total so far: 2675000)
# Requesting rows with offset 2675000...
# Retrieved 5000 rows (total so far: 2680000)
# Requesting rows with offset 2680000...
# Retrieved 5000 rows (total so far: 2685000)
# Requesting rows with offset 2685000...
# Retrieved 5000 rows (total so far: 2690000)
# Requesting rows with offset 2690000...
# Retrieved 5000 rows (total so far: 2695000)
# Requesting rows with offset 2695000...
# Retrieved 5000 rows (total so far: 2700000)
# Requesting rows with offset 2700000...
# Retrieved 5000 rows (total so far: 2705000)
# Requesting rows with offset 2705000...
# Retrieved 5000 rows (total so far: 2710000)
# Requesting rows with offset 2710000...
# Retrieved 5000 rows (total so far: 2715000)
# Requesting rows with offset 2715000...
# Retrieved 5000 rows (total so far: 2720000)
# Requesting rows with offset 2720000...
# Retrieved 5000 rows (total so far: 2725000)
# Requesting rows with offset 2725000...
# Retrieved 5000 rows (total so far: 2730000)
# Requesting rows with offset 2730000...
# Retrieved 5000 rows (total so far: 2735000)
# Requesting rows with offset 2735000...
# Retrieved 5000 rows (total so far: 2740000)
# Requesting rows with offset 2740000...
# Retrieved 5000 rows (total so far: 2745000)
# Requesting rows with offset 2745000...
# Retrieved 5000 rows (total so far: 2750000)
# Requesting rows with offset 2750000...
# Retrieved 5000 rows (total so far: 2755000)
# Requesting rows with offset 2755000...
# Retrieved 5000 rows (total so far: 2760000)
# Requesting rows with offset 2760000...
# Retrieved 5000 rows (total so far: 2765000)
# Requesting rows with offset 2765000...
# Retrieved 5000 rows (total so far: 2770000)
# Requesting rows with offset 2770000...
# Retrieved 5000 rows (total so far: 2775000)
# Requesting rows with offset 2775000...
# Retrieved 5000 rows (total so far: 2780000)
# Requesting rows with offset 2780000...
# Retrieved 5000 rows (total so far: 2785000)
# Requesting rows with offset 2785000...
# Retrieved 5000 rows (total so far: 2790000)
# Requesting rows with offset 2790000...
# Retrieved 5000 rows (total so far: 2795000)
# Requesting rows with offset 2795000...
# Retrieved 5000 rows (total so far: 2800000)
# Requesting rows with offset 2800000...
# Retrieved 5000 rows (total so far: 2805000)
# Requesting rows with offset 2805000...
# Retrieved 5000 rows (total so far: 2810000)
# Requesting rows with offset 2810000...
# Retrieved 5000 rows (total so far: 2815000)
# Requesting rows with offset 2815000...
# Retrieved 5000 rows (total so far: 2820000)
# Requesting rows with offset 2820000...
# Retrieved 5000 rows (total so far: 2825000)
# Requesting rows with offset 2825000...
# Retrieved 5000 rows (total so far: 2830000)
# Requesting rows with offset 2830000...
# Retrieved 5000 rows (total so far: 2835000)
# Requesting rows with offset 2835000...
# Retrieved 5000 rows (total so far: 2840000)
# Requesting rows with offset 2840000...
# Retrieved 5000 rows (total so far: 2845000)
# Requesting rows with offset 2845000...
# Retrieved 5000 rows (total so far: 2850000)
# Requesting rows with offset 2850000...
# Retrieved 5000 rows (total so far: 2855000)
# Requesting rows with offset 2855000...
# Retrieved 5000 rows (total so far: 2860000)
# Requesting rows with offset 2860000...
# Retrieved 5000 rows (total so far: 2865000)
# Requesting rows with offset 2865000...
# Retrieved 5000 rows (total so far: 2870000)
# Requesting rows with offset 2870000...
# Retrieved 5000 rows (total so far: 2875000)
# Requesting rows with offset 2875000...
# Retrieved 5000 rows (total so far: 2880000)
# Requesting rows with offset 2880000...
# Retrieved 5000 rows (total so far: 2885000)
# Requesting rows with offset 2885000...
# Retrieved 5000 rows (total so far: 2890000)
# Requesting rows with offset 2890000...
# Retrieved 5000 rows (total so far: 2895000)
# Requesting rows with offset 2895000...
# Retrieved 5000 rows (total so far: 2900000)
# Requesting rows with offset 2900000...
# Retrieved 5000 rows (total so far: 2905000)
# Requesting rows with offset 2905000...
# Retrieved 5000 rows (total so far: 2910000)
# Requesting rows with offset 2910000...
# Retrieved 5000 rows (total so far: 2915000)
# Requesting rows with offset 2915000...
# Retrieved 5000 rows (total so far: 2920000)
# Requesting rows with offset 2920000...
# Retrieved 5000 rows (total so far: 2925000)
# Requesting rows with offset 2925000...
# Retrieved 5000 rows (total so far: 2930000)
# Requesting rows with offset 2930000...
# Retrieved 5000 rows (total so far: 2935000)
# Requesting rows with offset 2935000...
# Retrieved 5000 rows (total so far: 2940000)
# Requesting rows with offset 2940000...
# Retrieved 5000 rows (total so far: 2945000)
# Requesting rows with offset 2945000...
# Retrieved 5000 rows (total so far: 2950000)
# Requesting rows with offset 2950000...
# Retrieved 5000 rows (total so far: 2955000)
# Requesting rows with offset 2955000...
# Retrieved 5000 rows (total so far: 2960000)
# Requesting rows with offset 2960000...
# Retrieved 5000 rows (total so far: 2965000)
# Requesting rows with offset 2965000...
# Retrieved 5000 rows (total so far: 2970000)
# Requesting rows with offset 2970000...
# Retrieved 5000 rows (total so far: 2975000)
# Requesting rows with offset 2975000...
# Retrieved 5000 rows (total so far: 2980000)
# Requesting rows with offset 2980000...
# Retrieved 5000 rows (total so far: 2985000)
# Requesting rows with offset 2985000...
# Retrieved 5000 rows (total so far: 2990000)
# Requesting rows with offset 2990000...
# Retrieved 5000 rows (total so far: 2995000)
# Requesting rows with offset 2995000...
# Retrieved 5000 rows (total so far: 3000000)
# Requesting rows with offset 3000000...
# Retrieved 5000 rows (total so far: 3005000)
# Requesting rows with offset 3005000...
# Retrieved 5000 rows (total so far: 3010000)
# Requesting rows with offset 3010000...
# Retrieved 5000 rows (total so far: 3015000)
# Requesting rows with offset 3015000...
# Retrieved 5000 rows (total so far: 3020000)
# Requesting rows with offset 3020000...
# Retrieved 5000 rows (total so far: 3025000)
# Requesting rows with offset 3025000...
# Retrieved 5000 rows (total so far: 3030000)
# Requesting rows with offset 3030000...
# Retrieved 5000 rows (total so far: 3035000)
# Requesting rows with offset 3035000...
# Retrieved 5000 rows (total so far: 3040000)
# Requesting rows with offset 3040000...
# Retrieved 5000 rows (total so far: 3045000)
# Requesting rows with offset 3045000...
# Retrieved 5000 rows (total so far: 3050000)
# Requesting rows with offset 3050000...
# Retrieved 5000 rows (total so far: 3055000)
# Requesting rows with offset 3055000...
# Retrieved 5000 rows (total so far: 3060000)
# Requesting rows with offset 3060000...
# Retrieved 5000 rows (total so far: 3065000)
# Requesting rows with offset 3065000...
# Retrieved 5000 rows (total so far: 3070000)
# Requesting rows with offset 3070000...
# Retrieved 5000 rows (total so far: 3075000)
# Requesting rows with offset 3075000...
# Retrieved 5000 rows (total so far: 3080000)
# Requesting rows with offset 3080000...
# Retrieved 5000 rows (total so far: 3085000)
# Requesting rows with offset 3085000...
# Retrieved 5000 rows (total so far: 3090000)
# Requesting rows with offset 3090000...
# Retrieved 5000 rows (total so far: 3095000)
# Requesting rows with offset 3095000...
# Retrieved 5000 rows (total so far: 3100000)
# Requesting rows with offset 3100000...
# Retrieved 5000 rows (total so far: 3105000)
# Requesting rows with offset 3105000...
# Retrieved 5000 rows (total so far: 3110000)
# Requesting rows with offset 3110000...
# Retrieved 5000 rows (total so far: 3115000)
# Requesting rows with offset 3115000...
# Retrieved 5000 rows (total so far: 3120000)
# Requesting rows with offset 3120000...
# Retrieved 5000 rows (total so far: 3125000)
# Requesting rows with offset 3125000...
# Retrieved 5000 rows (total so far: 3130000)
# Requesting rows with offset 3130000...
# Retrieved 5000 rows (total so far: 3135000)
# Requesting rows with offset 3135000...
# Retrieved 5000 rows (total so far: 3140000)
# Requesting rows with offset 3140000...
# Retrieved 5000 rows (total so far: 3145000)
# Requesting rows with offset 3145000...
# Retrieved 5000 rows (total so far: 3150000)
# Requesting rows with offset 3150000...
# Retrieved 5000 rows (total so far: 3155000)
# Requesting rows with offset 3155000...
# Retrieved 5000 rows (total so far: 3160000)
# Requesting rows with offset 3160000...
# Retrieved 5000 rows (total so far: 3165000)
# Requesting rows with offset 3165000...
# Retrieved 5000 rows (total so far: 3170000)
# Requesting rows with offset 3170000...
# Retrieved 5000 rows (total so far: 3175000)
# Requesting rows with offset 3175000...
# Retrieved 5000 rows (total so far: 3180000)
# Requesting rows with offset 3180000...
# Retrieved 5000 rows (total so far: 3185000)
# Requesting rows with offset 3185000...
# Retrieved 5000 rows (total so far: 3190000)
# Requesting rows with offset 3190000...
# Retrieved 5000 rows (total so far: 3195000)
# Requesting rows with offset 3195000...
# Retrieved 5000 rows (total so far: 3200000)
# Requesting rows with offset 3200000...
# Retrieved 5000 rows (total so far: 3205000)
# Requesting rows with offset 3205000...
# Retrieved 5000 rows (total so far: 3210000)
# Requesting rows with offset 3210000...
# Retrieved 5000 rows (total so far: 3215000)
# Requesting rows with offset 3215000...
# Retrieved 5000 rows (total so far: 3220000)
# Requesting rows with offset 3220000...
# Retrieved 5000 rows (total so far: 3225000)
# Requesting rows with offset 3225000...
# Retrieved 5000 rows (total so far: 3230000)
# Requesting rows with offset 3230000...
# Retrieved 5000 rows (total so far: 3235000)
# Requesting rows with offset 3235000...
# Retrieved 5000 rows (total so far: 3240000)
# Requesting rows with offset 3240000...
# Retrieved 5000 rows (total so far: 3245000)
# Requesting rows with offset 3245000...
# Retrieved 5000 rows (total so far: 3250000)
# Requesting rows with offset 3250000...
# Retrieved 5000 rows (total so far: 3255000)
# Requesting rows with offset 3255000...
# Retrieved 5000 rows (total so far: 3260000)
# Requesting rows with offset 3260000...
# Retrieved 5000 rows (total so far: 3265000)
# Requesting rows with offset 3265000...
# Retrieved 5000 rows (total so far: 3270000)
# Requesting rows with offset 3270000...
# Retrieved 5000 rows (total so far: 3275000)
# Requesting rows with offset 3275000...
# Retrieved 5000 rows (total so far: 3280000)
# Requesting rows with offset 3280000...
# Retrieved 5000 rows (total so far: 3285000)
# Requesting rows with offset 3285000...
# Retrieved 5000 rows (total so far: 3290000)
# Requesting rows with offset 3290000...
# Retrieved 5000 rows (total so far: 3295000)
# Requesting rows with offset 3295000...
# Retrieved 5000 rows (total so far: 3300000)
# Requesting rows with offset 3300000...
# Retrieved 5000 rows (total so far: 3305000)
# Requesting rows with offset 3305000...
# Retrieved 5000 rows (total so far: 3310000)
# Requesting rows with offset 3310000...
# Retrieved 5000 rows (total so far: 3315000)
# Requesting rows with offset 3315000...
# Retrieved 5000 rows (total so far: 3320000)
# Requesting rows with offset 3320000...
# Retrieved 5000 rows (total so far: 3325000)
# Requesting rows with offset 3325000...
# Retrieved 5000 rows (total so far: 3330000)
# Requesting rows with offset 3330000...
# Retrieved 5000 rows (total so far: 3335000)
# Requesting rows with offset 3335000...
# Retrieved 5000 rows (total so far: 3340000)
# Requesting rows with offset 3340000...
# Retrieved 5000 rows (total so far: 3345000)
# Requesting rows with offset 3345000...
# Retrieved 5000 rows (total so far: 3350000)
# Requesting rows with offset 3350000...
# Retrieved 5000 rows (total so far: 3355000)
# Requesting rows with offset 3355000...
# Retrieved 5000 rows (total so far: 3360000)
# Requesting rows with offset 3360000...
# Retrieved 5000 rows (total so far: 3365000)
# Requesting rows with offset 3365000...
# Retrieved 5000 rows (total so far: 3370000)
# Requesting rows with offset 3370000...
# Retrieved 5000 rows (total so far: 3375000)
# Requesting rows with offset 3375000...
# Retrieved 5000 rows (total so far: 3380000)
# Requesting rows with offset 3380000...
# Retrieved 5000 rows (total so far: 3385000)
# Requesting rows with offset 3385000...
# Retrieved 5000 rows (total so far: 3390000)
# Requesting rows with offset 3390000...
# Retrieved 5000 rows (total so far: 3395000)
# Requesting rows with offset 3395000...
# Retrieved 5000 rows (total so far: 3400000)
# Requesting rows with offset 3400000...
# Retrieved 5000 rows (total so far: 3405000)
# Requesting rows with offset 3405000...
# Retrieved 5000 rows (total so far: 3410000)
# Requesting rows with offset 3410000...
# Retrieved 5000 rows (total so far: 3415000)
# Requesting rows with offset 3415000...
# Retrieved 5000 rows (total so far: 3420000)
# Requesting rows with offset 3420000...
# Retrieved 5000 rows (total so far: 3425000)
# Requesting rows with offset 3425000...
# Retrieved 2151 rows (total so far: 3427151)
# Last page reached.
# Finished retrieving data.
# Total rows fetched: 3427151

# %%
import pandas as pd

pd.DataFrame(all_data).to_parquet("data/eia_hourly_generation_2025.parquet")
